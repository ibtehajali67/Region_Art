# %%
# import cv2
# import numpy as np
# from collections import defaultdict 
# img = cv2.imread('9/out1.png')
# pixels = img.reshape(-1,3)
# counts = defaultdict(int)
# for pixel in pixels:
#     if pixel[0] == pixel[1] == pixel[2]:
#        counts[pixel[0]] += 1
# for pv in sorted(counts.keys()):
#     print("(%d,%d,%d): %d pixels" % (pv, pv, pv, counts[pv]))



#***count white pixels
from PIL import Image  
im = Image.open('9/out1.png')
white=0
other=0
for pixel in im.getdata():
    if pixel == (255, 255, 255): # if your image is RGB (if RGBA, (0, 0,     0, 255) or so
        white+=1
    else:
        other+=1
print('white=' + str(white)+', Other='+str(other))

# %%
import cv2
import numpy as np
image = cv2.imread("app1.jpg")
image[np.where((image==[0, 0, 0]).all(axis=2))] = [0,0,255]
cv2.imwrite("h.jpg",image)

# %%
from PIL import Image  
import glob
count=1
for infile in sorted(glob.glob('7/*.png')):
    print(infile)
    im1 = Image.open(infile)
    im1.save('11/'+str(count)+'.jpg')
    count+=1
# Out:
# 7/0current_region.png
# 7/100current_region.png
# 7/101current_region.png
# 7/102current_region.png
# 7/103current_region.png
# 7/104current_region.png
# 7/10current_region.png
# 7/11current_region.png
# 7/12current_region.png
# 7/13current_region.png
# 7/14current_region.png
# 7/15current_region.png
# 7/16current_region.png
# 7/17current_region.png
# 7/18current_region.png
# 7/19current_region.png
# 7/1current_region.png
# 7/20current_region.png
# 7/21current_region.png
# 7/22current_region.png
# 7/23current_region.png
# 7/24current_region.png
# 7/25current_region.png
# 7/26current_region.png
# 7/27current_region.png
# 7/28current_region.png
# 7/29current_region.png
# 7/2current_region.png
# 7/30current_region.png
# 7/31current_region.png
# 7/32current_region.png
# 7/33current_region.png
# 7/34current_region.png
# 7/35current_region.png
# 7/36current_region.png
# 7/37current_region.png
# 7/38current_region.png
# 7/39current_region.png
# 7/3current_region.png
# ...
